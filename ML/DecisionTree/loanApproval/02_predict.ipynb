# %%
from module import predict_loan_approval

# %%
# 승인되는 경우
result = predict_loan_approval(points_bin='High', credit_score=650, income=70000)
print("승인 여부:", result)
# Out:
# 승인 여부: True

# %%
# 점수가 Low인 경우
result = predict_loan_approval(points_bin='Low', credit_score=700, income=80000)
print("승인 여부:", result)
# Out:
# 승인 여부: False

# %%
# 신용 점수가 낮은 경우
result = predict_loan_approval(points_bin='Medium', credit_score=570, income=90000)
print("승인 여부:", result)
# Out:
# 승인 여부: False

# %%
# 소득이 낮은 경우
result = predict_loan_approval(points_bin='Medium', credit_score=600, income=60000)
print("승인 여부:", result)
# Out:
# 승인 여부: False
